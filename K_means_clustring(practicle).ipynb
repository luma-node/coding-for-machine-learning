# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("/content/IRIS.csv")

# %%
dataset.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
wcss = []

for i in range(2,21):
  km = KMeans(n_clusters=i, init='k-means++')
  km.fit(dataset.drop('species', axis=1)) # Select only numerical columns
  wcss.append(km.inertia_)

# %%
plt.figure(figsize=(10, 5))
plt.plot([i for i in range(2, 21)], wcss,marker="o")
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.xticks([i for i in range(2,21)])
plt.ylabel('WCSS')
plt.grid()
plt.show()

# %%
kmn =  KMeans(n_clusters=3)
dataset["predict"] = kmn.fit_predict

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#                                                predict
# 0    <bound method _BaseKMeans.fit_predict of KMean...
# 1    <bound method _BaseKMeans.fit_predict of KMean...
# 2    <bound method _BaseKMeans.fit_predict of KMean...
# 3    <bound method _BaseKMeans.fit_predict of KMean...
# 4    <bound method _BaseKMeans.fit_predict of KMean...
# ..                                                 ...
# 145  <bound method _BaseKMeans.fit_predict of KMean...
# 146  <bound method _BaseKMeans.fit_predict of KMean...
# 147  <bound method _BaseKMeans.fit_predict of KMean...
# 148  <bound method _BaseKMeans.fit_predict of KMean...
# 149  <bound method _BaseKMeans.fit_predict of KMean...
#
# [150 rows x 6 columns]

# %%
sns.pairplot(data=dataset,hue="predict")
plt.show()

# %%
org_dataset = pd.read_csv(r"/content/IRIS.csv")

# %%
sns.pairplot(data=org_dataset,hue="species")
plt.show()
